# %% [markdown]
# <a href="https://colab.research.google.com/github/sudipsardar922603-dotcom/MtechProjects/blob/feature%2Ftesting/Zeroshot_testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Install Required Libraries

# %%
# !pip install transformers datasets accelerate setfit torch
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 5.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# Authenticating with Hugging Face Hub

# %%
from huggingface_hub import notebook_login
notebook_login()

# %% [markdown]
# Loading a Zero-Shot Pipeline

# %%
from transformers import pipeline

classifier = pipeline("zero-shot-classification",
                      model="facebook/bart-large-mnli")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Device set to use cpu

# %% [markdown]
# Runing Zero-Shot Classification

# %%
sequence = "This movie was absolutely wonderful and inspiring."
labels = ["positive", "negative", "neutral"]

result = classifier(sequence, candidate_labels=labels)
print(result)
# Out:
# {'sequence': 'This movie was absolutely wonderful and inspiring.', 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.9931159615516663, 0.00419094180688262, 0.002693117130547762]}

# %%
sequence = "the pyspark code was  really difficult to debug from scrach"
labels = ["positive", "negative", "neutral"]

result = classifier(sequence, candidate_labels=labels)
print(result)
# Out:
# {'sequence': 'the pyspark code was  really difficult to debug from scrach', 'labels': ['negative', 'neutral', 'positive'], 'scores': [0.6979358196258545, 0.1906467080116272, 0.11141747236251831]}

# %%
sequence = "The scool boy met with an seriou accident while crossing the road"
labels = ["positive", "negative", "neutral"]

result = classifier(sequence, candidate_labels=labels)
print(result)
# Out:
# {'sequence': 'The scool boy met with an seriou accident while crossing the road', 'labels': ['negative', 'neutral', 'positive'], 'scores': [0.9702392220497131, 0.015930239111185074, 0.013830606825649738]}

# %% [markdown]
# Sentiment analysis - testing

# %%
sequence = "The food was absolutely delicious and the service was excellent."
labels = ["positive", "negative", "neutral"]

result = classifier(sequence, candidate_labels=labels)
print(result)
# Out:
# {'sequence': 'The food was absolutely delicious and the service was excellent.', 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.9863595962524414, 0.009256992489099503, 0.004383431747555733]}

# %% [markdown]
# Topic Classification - testing

# %%
sequence = "The government announced new policies on renewable energy."
labels = ["politics", "sports", "technology", "health"]

result = classifier(sequence, candidate_labels=labels)
print(result)
# Out:
# {'sequence': 'The government announced new policies on renewable energy.', 'labels': ['politics', 'technology', 'health', 'sports'], 'scores': [0.49480554461479187, 0.459059476852417, 0.024740595370531082, 0.021394377574324608]}

# %% [markdown]
# Intent detection -  testing

# %%
sequence = "Can you tell me the balance of my account?"
labels = ["check_balance", "transfer_money", "open_account", "general_query"]

result = classifier(sequence, candidate_labels=labels)
print(result)
# Out:
# {'sequence': 'Can you tell me the balance of my account?', 'labels': ['open_account', 'general_query', 'check_balance', 'transfer_money'], 'scores': [0.35865819454193115, 0.2653132379055023, 0.2533600330352783, 0.12266855686903]}
